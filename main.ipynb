# %%
# !pip install python-telegram-bot nest_asyncio yfinance python-dotenv --quiet

# %%
# !pip install pandas numpy scikit-learn prophet tensorflow --quiet

# %%
import nest_asyncio
import asyncio

from run_bot import main_async

# %%
# для предотвращения ошибки "This event loop is already running"
nest_asyncio.apply()

task = asyncio.create_task(main_async())
# Out:
# 2026-01-11 20:56:54,849 [INFO] Бот запускается...
# 2026-01-11 20:56:54,895 [INFO] Бот запущен!

# %%
# task.cancel()
# Out:
# True
